# %%
import pandas as pd
import pandas_datareader.data as web
import sklearn.mixture as mix

import numpy as np
import scipy.stats as scs

import matplotlib as mpl
from matplotlib import cm
import matplotlib.pyplot as plt
from matplotlib.dates import YearLocator, MonthLocator
from sklearn.cluster import MiniBatchKMeans as kmean
# %matplotlib inline

import seaborn as sns
import missingno as msno
from tqdm import tqdm

# %%
f1 = 'TEDRATE' # ted spread
f2 = 'T10Y2Y' # constant maturity ten yer - 2 year
f3 = 'T10Y3M' # constant maturity 10yr - 3m

start = pd.to_datetime('2002-01-01')
end = pd.datetime.today()

mkt = 'SPY'
MKT = (web.DataReader([mkt], 'google', start, end)['Close']
       .rename(columns={mkt:mkt})
       .assign(sret=lambda x: np.log(x[mkt]/x[mkt].shift(1)))
       .dropna())
print(MKT['SPY'])

data = (web.DataReader([f1, f2, f3], 'fred', start, end)
        .join(MKT, how='inner')
        .dropna()
       )

print(data.head())

# gives us a quick visual inspection of the data
msno.matrix(data)
# Out:
# Date
# 2002-01-03    116.84
# 2002-01-04    117.62
# 2002-01-07    116.79
# 2002-01-08    116.52
# 2002-01-09    115.57
# 2002-01-10    116.08
# 2002-01-11    114.94
# 2002-01-14    114.22
# 2002-01-15    115.15
# 2002-01-16    112.82
# 2002-01-17    113.67
# 2002-01-18    113.15
# 2002-01-22    112.37
# 2002-01-23    113.23
# 2002-01-24    113.58
# 2002-01-25    113.55
# 2002-01-28    113.86
# 2002-01-29    110.28
# 2002-01-30    111.87
# 2002-01-31    113.18
# 2002-02-01    112.65
# 2002-02-04    109.85
# 2002-02-05    109.17
# 2002-02-06    108.70
# 2002-02-07    108.02
# 2002-02-08    110.09
# 2002-02-11    111.44
# 2002-02-12    111.09
# 2002-02-13    112.27
# 2002-02-14    112.06
#                ...
# 2017-04-21    234.59
# 2017-04-24    237.17
# 2017-04-25    238.55
# 2017-04-26    238.40
# 2017-04-27    238.60
# 2017-04-28    238.08
# 2017-05-01    238.68
# 2017-05-02    238.77
# 2017-05-03    238.48
# 2017-05-04    238.76
# 2017-05-05    239.70
# 2017-05-08    239.66
# 2017-05-09    239.44
# 2017-05-10    239.87
# 2017-05-11    239.38
# 2017-05-12    238.98
# 2017-05-15    240.30
# 2017-05-16    240.08
# 2017-05-17    235.82
# 2017-05-18    236.77
# 2017-05-19    238.31
# 2017-05-22    239.52
# 2017-05-23    240.05
# 2017-05-24    240.61
# 2017-05-25    241.76
# 2017-05-26    241.71
# 2017-05-30    241.50
# 2017-05-31    241.44
# 2017-06-01    243.36
# 2017-06-02    244.17
# Name: SPY, dtype: float64
#             TEDRATE  T10Y2Y  T10Y3M     SPY      sret
# 2002-01-03     0.18    1.97    3.43  116.84  0.011275
# 2002-01-04     0.18    1.99    3.46  117.62  0.006654
# 2002-01-07     0.22    2.01    3.41  116.79 -0.007082
# 2002-01-08     0.19    2.03    3.42  116.52 -0.002315
# 2002-01-09     0.19    2.07    3.42  115.57 -0.008187

# %%
col = 'sret'
select = data.ix[:].dropna()

ft_cols = [f1, f2, f3, 'sret']
X = select[ft_cols].values
print(X)

model = mix.GaussianMixture(n_components=3, 
                            covariance_type="full", 
                            n_init=200, 
                            random_state=10).fit(X)
# model = kmean(n_clusters=6).fit(X)

# Predict the optimal sequence of internal hidden state
hidden_states = model.predict(X)
# hidden_states = model.predict(X)

print("Means and vars of each hidden state")
for i in range(model.n_components):
    print("{0}th hidden state".format(i))
    print("mean = ", model.means_[i])
    print("var = ", np.diag(model.covariances_[i]))
    print()

sns.set(font_scale=1.25)
style_kwds = {'xtick.major.size': 6, 'ytick.major.size': 6,
              'font.family':u'courier prime code', 'legend.frameon': True}
sns.set_style('white', style_kwds)

fig, axs = plt.subplots(model.n_components, sharex=True, sharey=True, figsize=(12,9))
colors = cm.rainbow(np.linspace(0, 1, model.n_components))

for i, (ax, color) in enumerate(zip(axs, colors)):
    # Use fancy indexing to plot data in each state.
    mask = hidden_states == i
    ax.plot_date(select.index.values[mask],
                 select[col].values[mask],
                 ".-", c=color)
    ax.set_title("{0}th hidden state".format(i), fontsize=16, fontweight='demi')

    # Format the ticks.
    ax.xaxis.set_major_locator(YearLocator())
    ax.xaxis.set_minor_locator(MonthLocator())
    sns.despine(offset=10)

plt.tight_layout()
fig.savefig('Hidden Markov (Mixture) Model_Regime Subplots.png')
# Out:
# [[  1.80000000e-01   1.97000000e+00   3.43000000e+00   1.12752410e-02]
#  [  1.80000000e-01   1.99000000e+00   3.46000000e+00   6.65361151e-03]
#  [  2.20000000e-01   2.01000000e+00   3.41000000e+00  -7.08163874e-03]
#  ...,
#  [  2.80000000e-01   9.70000000e-01   1.33000000e+00   2.33013046e-03]
#  [  2.80000000e-01   9.50000000e-01   1.31000000e+00   4.76813309e-03]
#  [  2.80000000e-01   9.50000000e-01   1.31000000e+00  -2.06838067e-04]]
# Means and vars of each hidden state
# 0th hidden state
# ('mean = ', array([  1.12934396e+00,   1.59065758e+00,   2.08559475e+00,
#         -1.18249721e-03]))
# ('var = ', array([  5.24296939e-01,   3.38906117e-01,   7.80620880e-01,
#          4.88676779e-04]))
# ()
# 1th hidden state
# ('mean = ', array([ 0.47941509,  0.03969899,  0.08832919,  0.00060319]))
# ('var = ', array([  1.16647685e-02,   1.79079303e-02,   1.85245871e-01,
#          4.11963815e-05]))
# ()
# 2th hidden state
# ('mean = ', array([  2.59634600e-01,   1.86710362e+00,   2.45539688e+00,
#          3.59156719e-04]))
# ('var = ', array([  9.02354405e-03,   3.54448555e-01,   4.99156540e-01,
#          8.16141304e-05]))
# ()

# %%
import numpy as np
# Kmean
col = 'sret'
select = data.ix[:].dropna()

ft_cols = [f1, f2, f3, 'sret']
X = select[ft_cols].values
XXX =  np.array(MKT['SPY'])
XXX = [[x] for x in XXX]

# model = mix.GaussianMixture(n_components=6, 
#                             covariance_type="full", 
#                             n_init=100, 
#                             random_state=7).fit(X)
model = kmean(init='k-means++', n_clusters=3, n_init=20, max_iter=30).fit(X)

# Predict the optimal sequence of internal hidden state
# hidden_states = model.predict(X)
hidden_states = model.predict(X)

print("Means and vars of each hidden state")
for i in range(model.n_clusters):
    print("{0}th hidden state".format(i))
    print("mean = ", model.cluster_centers_[i])
    print()

sns.set(font_scale=1.25)
style_kwds = {'xtick.major.size': 6, 'ytick.major.size': 6,
              'font.family':u'courier prime code', 'legend.frameon': True}
sns.set_style('white', style_kwds)

fig, axs = plt.subplots(model.n_clusters, sharex=True, sharey=True, figsize=(12,9))
colors = cm.rainbow(np.linspace(0, 1, model.n_clusters))

for i, (ax, color) in enumerate(zip(axs, colors)):
    # Use fancy indexing to plot data in each state.
    mask = hidden_states == i
    ax.plot_date(select.index.values[mask],
                 select[col].values[mask],
                 ".-", c=color)
    ax.set_title("{0}th hidden state".format(i), fontsize=16, fontweight='demi')

    # Format the ticks.
    ax.xaxis.set_major_locator(YearLocator())
    ax.xaxis.set_minor_locator(MonthLocator())
    sns.despine(offset=10)

plt.tight_layout()
# fig.savefig('Hidden Markov (Mixture) Model_Regime Subplots.png')
# Out:
# Means and vars of each hidden state
# 0th hidden state
# ('mean = ', array([  3.20647450e-01,   2.31016408e+00,   3.01330820e+00,
#         -2.43671746e-04]))
# ()
# 1th hidden state
# ('mean = ', array([  6.31214575e-01,   1.41528340e-01,   1.89919028e-01,
#          5.63534760e-04]))
# ()
# 2th hidden state
# ('mean = ', array([  4.72011520e-01,   1.40462118e+00,   1.88406735e+00,
#          5.87671087e-05]))
# ()

# %%
sns.set(font_scale=1.5)
states = (pd.DataFrame(hidden_states, columns=['states'], index=select.index)
          .join(select, how='inner')
          .assign(mkt_cret=select.sret.cumsum())
          .reset_index(drop=False)
          .rename(columns={'index':'Date'}))
print(states.head())

sns.set_style('white', style_kwds)
order = [0, 1, 2, 3, 4, 5]
fg = sns.FacetGrid(data=states, hue='states', hue_order=order,
                   palette=colors, aspect=1.31, size=12)
fg.map(plt.scatter, 'Date', mkt, alpha=0.8).add_legend()
sns.despine(offset=10)
fg.fig.suptitle('Historical SPY Regimes', fontsize=24, fontweight='demi')
fg.savefig('Hidden Markov (Mixture) Model_SPY Regimes.png')
# Out:
#         Date  states  TEDRATE  T10Y2Y  T10Y3M     SPY      sret  mkt_cret
# 0 2002-01-03       0     0.18    1.97    3.43  116.84  0.011275  0.011275
# 1 2002-01-04       0     0.18    1.99    3.46  117.62  0.006654  0.017929
# 2 2002-01-07       0     0.22    2.01    3.41  116.79 -0.007082  0.010847
# 3 2002-01-08       0     0.19    2.03    3.42  116.52 -0.002315  0.008533
# 4 2002-01-09       0     0.19    2.07    3.42  115.57 -0.008187  0.000346

# %%
sns.set(font_scale=1.5)
states = (pd.DataFrame(hidden_states, columns=['states'], index=select.index)
          .join(select, how='inner')
          .assign(mkt_cret=select.sret.cumsum())
          .reset_index(drop=False)
          .rename(columns={'index':'Date'}))
print(states.head())

sns.set_style('white', style_kwds)
order = [0, 1, 2, 3, 4, 5]
fg = sns.FacetGrid(data=states, hue='states', hue_order=order,
                   palette=colors, aspect=1.31, size=12)
fg.map(plt.scatter, 'Date', mkt, alpha=0.8).add_legend()
sns.despine(offset=10)
fg.fig.suptitle('Historical SPY Regimes', fontsize=24, fontweight='demi')
fg.savefig('Hidden Markov (Mixture) Model_SPY Regimes.png')
# Out:
#         Date  states  TEDRATE  T10Y2Y  T10Y3M     SPY      sret  mkt_cret
# 0 2002-01-03       2     0.18    1.97    3.43  116.84  0.011275  0.011275
# 1 2002-01-04       2     0.18    1.99    3.46  117.62  0.006654  0.017929
# 2 2002-01-07       2     0.22    2.01    3.41  116.79 -0.007082  0.010847
# 3 2002-01-08       2     0.19    2.03    3.42  116.52 -0.002315  0.008533
# 4 2002-01-09       2     0.19    2.07    3.42  115.57 -0.008187  0.000346

# %%
startx = pd.to_datetime('2010-01-01')
endx = pd.datetime.today()
test = web.DataReader('google', startx, endx)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-81-057d8d7cf261> in <module>()
#       1 startx = pd.to_datetime('2010-01-01')
#       2 endx = pd.datetime.today()
# ----> 3 test = web.DataReader('google', startx, endx)
#
# c:\python27\lib\site-packages\pandas_datareader\data.pyc in DataReader(name, data_source, start, end, retry_count, pause, session, access_key)
#     171     else:
#     172         msg = "data_source=%r is not implemented" % data_source
# --> 173         raise NotImplementedError(msg)
#     174
#     175
#
# NotImplementedError: data_source=Timestamp('2010-01-01 00:00:00') is not implemented

# %%
print(test)
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 5 (items) x 1867 (major_axis) x 1 (minor_axis)
# Items axis: Open to Volume
# Major_axis axis: 2010-01-04 00:00:00 to 2017-06-02 00:00:00
# Minor_axis axis: F to F

# %%
import matplotlib.pyplot as plt
